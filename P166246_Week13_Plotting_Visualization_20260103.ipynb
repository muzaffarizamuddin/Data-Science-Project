# %% [markdown]
# <a href="https://colab.research.google.com/github/muzaffarizamuddin/Data-Science-Project/blob/main/P166246_Week13_Plotting_Visualization_20260103.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Week 13: Plotting and Visualization using Matplotlib**
# Please refer to the textbook: "Python for Data Analysis" by Wes McKinney for details of this topic (***Chapter 9***)

# %% [markdown]
# # **Load Matplotlib library**

# %%
# Load library
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import pandas as pd
import seaborn as sns

# %% [markdown]
# # **Figure vs Axes**
# - **`Figure`** is the **entire window or page** that holds everything.
#     - It's the top-level container for all our plot elements
# - **`axes`** refer to the **actual plot area** where the data is drawn
#     - It's the part of the figure that contains the data space, ticks, labels, and titles
#     - We can have **multiple axes (subplots)** within a single figure.

# %%
# Create and display a simple scatter plot
x = np.arange(30)
y = x + 3*np.random.default_rng(12345).standard_normal(30)

# Creates a figure and a set of axes
fig, ax = plt.subplots()
ax.scatter(x, y)
ax.set(title="Scatter plot", xlabel="x", ylabel="y")
fig.show()

# %% [markdown]
# # **Simple 2 x 2 subplots grids**
# - **`constrained_layout=True`**
#     - automatically adjusts subplot parameters for a tight layout
#
# - Remember to save the figures first before executing **`plt.show()`**
#     - else the plot won't be save

# %%
rng = np.random.default_rng(12345)

data1 = rng.normal(0, 1, 100)
data2 = rng.normal(1, 1.5, 100)
x = np.arange(30)
y = x + rng.normal(0, 3, 30)

# Using subplot_mosaic to define a 2x2 grid
fig, mosaic_axs = plt.subplot_mosaic([['A', 'B'], ['C', 'D']], figsize=(8, 6), constrained_layout=True)

# (1) Histogram
mosaic_axs['A'].hist(data1, bins=30)
mosaic_axs['A'].set_title("Histogram of random number")

# (2) Scatter plot
mosaic_axs['B'].scatter(x, y)
mosaic_axs['B'].set_title("Scatter Plot")

# (3) Line plot
mosaic_axs['C'].plot(x, y)
mosaic_axs['C'].set_title("Line Plot")

# (4) Boxplot
mosaic_axs['D'].boxplot([data1, data2], tick_labels=["Group A", "Group B"])
mosaic_axs['D'].set_title("Boxplot")

# To save the figures
plt.savefig('/content/drive/MyDrive/Data/Figure.svg')

plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **More parameters on Individual plots**

# %% [markdown]
# ### **Histogram**
#
#
# *   **`bins`**: Bins are the intervals into which the data is divided for counting and display in the histogram.
#     - Having 20 bins means the data range will be split into 20 intervals
# *   **`alpha`**: controls the transparency of the bars.
#     - A value of 1.0 would be completely opaque, while 0.0 would be completely transparent.

# %%
# Histogram
rng = np.random.default_rng(12345)
plt.hist(rng.standard_normal(1000), bins=20,
         color='blue', alpha=0.6);

# %% [markdown]
# ### **linestyle**
# 1. some other options for the linestyle argument:
#
# *   `'-'` (**solid**): This is the default linestyle and creates a solid line.
# *   `'--'` (**dashed**): Creates a dashed line.
# *   `'-.'` (**dash-dot**): Creates a line with alternating dashes and dots.
# *   `':'` (**dotted**): Creates a dotted line.
# *   `'**None**'` or `' '` or `''` (no line): This will plot only markers if specified, or no line at all.
#
# 2. we can also use the shorter codes for these linestyles:
# *   **`solid`**: `-`
# *   **`dashed`**: `--`
# *   **`dashdot`**: `-.`
# *   **`dotted`**: `:`

# %%
# Line plot
rng = np.random.default_rng(12345)
plt.plot(rng.standard_normal(50).cumsum(),
         color='red', linestyle='--', label="bilangan ayam")
plt.legend();

# %%
import matplotlib.pyplot as plt

# Data for the pie chart
labels = ['Category A', 'Category B', 'Category C', 'Category D']
sizes = [15, 30, 45, 10] # Proportions of each category
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue'] # Colors for each slice
explode = (0.1, 0, 0, 0)  # "explode" the 1st slice (Category A)

# Create the pie chart
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.title("Distribution of Categories")
ax1.legend(title="Categories") # Add legend
plt.show()

# %% [markdown]
# ### **Pie Chart**
# A pie chart displays data as a circular graph divided into sectors, where each sector represents a proportion of the whole. It's often used to show the relative sizes of different categories within a single dataset.

# %% [markdown]
# # **Colors, Markers, and Line Styles**
#
# 1.   specify line styles using plt.plot documentation (***plt.plot?***)
# 2.   specify color using **hex code**, e.g. ***"#CECECE"***
# 3.   For more information, can visit this website: https://htmlcolorcodes.com/

# %% [markdown]
# ### **Marker**
# specify a symbol or shape that will be placed at each data point on the plotted line
#
# ### **Other Marker Options**
#
# Matplotlib offers a wide variety of marker options. Here are a few examples:
#
# * `'.'`: Point
# * `','`: Pixel
# * `'o'`: Circle
# * `'v'`: Triangle down
# * `'^'`: Triangle up
# * `'<'`: Triangle left
# * `'>'`: Triangle right
# * `'s'`: Square
# * `'+'`: Plus
# * `'x'`: X
# * `'D'`: Diamond
# * `'d'`: Thin diamond
# * `'|'`: Vertical line
# * `'_'`: Horizontal line

# %%
# Adding marker on line plot
rng = np.random.default_rng(12345)
plt.plot(rng.standard_normal(30).cumsum(), color='#FC03EC',
        linestyle='--', marker='*');

# %%
# Drawstyle default
rng = np.random.default_rng(12345)
data = rng.standard_normal(30).cumsum()
plt.plot(data, color='r', linestyle='dashed', label='Bernard')
plt.legend();

# %% [markdown]
# ### **Ticks, Labels, and Legends**
#
# 1.   parameter such as ***xlim([0, 10])*** sets the x-xis range from ***0 to 10***

# %% [markdown]
# ### ***Setting the title, axis labels, ticks, and tick labels***

# %%
# An example
rng = np.random.default_rng(12345)
fig, ax = plt.subplots()
ax.plot(rng.standard_normal(1000).cumsum())

# Changex x-axis ticks annotation
ax.set_xticks([0, 50, 500, 750, 1000])

# label the x-axis ticks with names
ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
                   rotation=30, fontsize=18)

ax.set_xlabel('Stages')
ax.set_ylabel('Values')
ax.set_title('My first matplotlib plot');

# %% [markdown]
# ### **Adding Legends**

# %%
# Adding legend
fig, ax = plt.subplots()
ax.plot(np.random.randn(1000).cumsum(), color='#FF7F00', label='one')
ax.plot(np.random.randn(1000).cumsum(), color='#377EB8', linestyle='dashed',
        label='two')
ax.plot(np.random.randn(1000).cumsum(), color='#4DAF4A', linestyle='dotted',
        label='three')
ax.legend(title='Trend');

# %%
# Saving the plot
fig.savefig('/content/drive/MyDrive/STQD6014_Executive/_SEM1_20252026/_Plots/LineChart_20260103.jpeg', dpi=400, bbox_inches="tight")

# %% [markdown]
# ### **Matplotlib Configuration**
# using ***rc*** method
#
# 1.   plt.rc('figure', figsize=(10, 10)) - to set the global default figure size to be 10 × 10
#
# 2.   plt.rcdefaults() -  restored to default values

# %%
# Adding shapes to a plot : Attention
fig, ax = plt.subplots()

rect = plt.Rectangle((0.2, 0.75), 0.2, 0.2, color='black', alpha=0.3)
circ = plt.Circle((0.6, 0.2), 0.15, color='blue', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6], [0.4, 0.8]],
                   color='green', alpha=0.5)
sqr = plt.Rectangle((0.3, 0.1), 0.2, 0.2, color='black', alpha=0.3)

# Add ellipse
ellipse = patches.Ellipse((0.5,0.5),0.3,0.1)

# Add regular hexagon
hexagon = patches.RegularPolygon((0.7,0.8),5, radius=0.1)

ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)
ax.add_patch(sqr)
ax.add_patch(ellipse)
ax.add_patch(hexagon);

# %%
# Set the previous shapes figure to 5 x 5
# and rerun
plt.rc('figure', figsize=(5, 5))

# %%
# Reset to default value
plt.rcdefaults()

# %% [markdown]
# ## **Plotting with pandas**

# %% [markdown]
# ### **Line plots**

# %%
# Using series data
rng = np.random.default_rng(12345)
s = pd.Series(rng.standard_normal(10).cumsum(),
              index=np.arange(0, 100, 10))
s.plot();

# %%
# Using Dataframe
rng = np.random.default_rng(12345)
df = pd.DataFrame(rng.standard_normal((10, 4)).cumsum(0),
                  columns=['A', 'B', 'C', 'D'],
                  index=np.arange(0, 100, 10))
df.plot();

# %% [markdown]
# ### **Bar plots**

# %%
# Series data
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.uniform(size=16), index=list('abcdefghijklmnop'))

# Plot.bar is for plotting vertical bar
data.plot.bar(ax=axes[0], color='navy', alpha=0.3)

# Plot.barh is for plotting horizontal bar
data.plot.barh(ax=axes[1], color='red', alpha=0.3);

# %%
# Example DataFrame
df = pd.DataFrame(np.random.uniform(size=(6, 4)),
                  index=['one', 'two', 'three', 'four', 'five', 'six'],
                  columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
df
# Out:
# Genus         A         B         C         D
# one    0.655642  0.616780  0.272990  0.364195
# two    0.700252  0.192309  0.891190  0.149887
# three  0.101132  0.924803  0.150427  0.481759
# four   0.176502  0.176624  0.811838  0.116258
# five   0.218207  0.380209  0.803723  0.142484
# six    0.068907  0.951700  0.398408  0.333691

# %%
# Grouped bar plot
df.plot.bar();

# %%
# Stacked bar plots
df.plot.barh(stacked=True, alpha=0.5);

# %%
# A dataset about restaurant tipping
tips = pd.read_csv('https://bit.ly/3jCROII')

# %%
# Show tips content
tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
# Create a frequency table
party_counts = pd.crosstab(tips['day'], tips['size'], margins=True)
party_counts
# Out:
# size  1    2   3   4  5  6  All
# day
# Fri   1   16   1   1  0  0   19
# Sat   2   53  18  13  1  0   87
# Sun   0   39  15  18  3  1   76
# Thur  1   48   4   5  1  3   62
# All   4  156  38  37  5  4  244

# %%
# Reorder the index
party_counts = party_counts.reindex(index=['Thur', 'Fri', 'Sat', 'Sun'])
party_counts
# Out:
# size  1   2   3   4  5  6  All
# day
# Thur  1  48   4   5  1  3   62
# Fri   1  16   1   1  0  0   19
# Sat   2  53  18  13  1  0   87
# Sun   0  39  15  18  3  1   76

# %%
# Extract party_count from col 2 to 5
party_counts = party_counts.loc[:, 2:5]

# %%
# Show content for party_counts
party_counts
# Out:
# size   2   3   4  5
# day
# Thur  48   4   5  1
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3

# %%
# Normalize each row to sum to 1
party_pcts = party_counts.div(party_counts.sum(axis='columns'),
                              axis=0)
party_pcts
# Out:
# size         2         3         4         5
# day
# Thur  0.827586  0.068966  0.086207  0.017241
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000

# %%
# Stacked bar plot
party_pcts.plot.bar(stacked=True);

# %% [markdown]
# ### **Plotting Using seaborn**
# ***seaborn*** is a high-level ***statistical graphics library*** built on matplotlib.
#
# - seaborn simplifies creating many common visualization types.

# %%
# Show content for tips
tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
# Add a new column for 'tip_pct'
tips['tip_pct'] = tips['tip'] / tips['total_bill']

# %%
# Show top five rows
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61     No  Sun  Dinner     4  0.146808

# %%
# Using black lines on the bars to represent 95% confidence interval
sns.barplot(x='tip_pct', y='day', data=tips, orient='h',
            order=['Thur', 'Fri', 'Sat', 'Sun']);

# %% [markdown]
# ### **`hue`**
# - `hue` helps to visualize the impact of an **additional categorical variable** on
# our main comparison.

# %%
# Using hue to add a categorical distinction
sns.barplot(x='tip_pct', y='day', hue='time', data=tips, orient='h',
            order=['Sun', 'Sat', 'Fri', 'Thur']);

# %% [markdown]
# ### **Histograms and Density Plots**
# discretized display of **value frequency**

# %%
# Display top few rows
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61     No  Sun  Dinner     4  0.146808

# %%
# Histogram
tips['tip_pct'].plot.hist(bins=50);

# %%
# Density plot
tips['tip_pct'].plot.density();

# %% [markdown]
# ### **Scatter or Point Plots**
# - examining the relationship between two one-dimensional data series

# %% [markdown]
# #### **Macro dataset**
# - Collection of economic data points that reflect the overall performance and health of a country, region, or the global economy.
# - **`m1`** represents the M1 money supply
#     - a measure of the most liquid forms of money within an economy, typically including physical currency (cash), demand deposits (checking accounts), and traveler's checks.
# - **`tbilrate`** is Treasury Bill Rate.
#     - the interest rate at which the government borrows money for short periods (usually less than a year) by issuing Treasury Bills.

# %%
# Example macro dataset
macro = pd.read_csv('https://bit.ly/3FYxCYZ')
macro
# Out:
#      year  quarter    realgdp  realcons   realinv  realgovt  realdpi      cpi  \
# 0    1959        1   2710.349    1707.4   286.898   470.045   1886.9   28.980
# 1    1959        2   2778.801    1733.7   310.859   481.301   1919.7   29.150
# 2    1959        3   2775.488    1751.8   289.226   491.260   1916.4   29.350
# 3    1959        4   2785.204    1753.7   299.356   484.052   1931.3   29.370
# 4    1960        1   2847.699    1770.5   331.722   462.199   1955.5   29.540
# ..    ...      ...        ...       ...       ...       ...      ...      ...
# 198  2008        3  13324.600    9267.7  1990.693   991.551   9838.3  216.889
# 199  2008        4  13141.920    9195.3  1857.661  1007.273   9920.4  212.174
# 200  2009        1  12925.410    9209.2  1558.494   996.287   9926.4  212.671
# 201  2009        2  12901.504    9189.0  1456.678  1023.528  10077.5  214.469
# 202  2009        3  12990.341    9256.0  1486.398  1044.088  10040.6  216.385
#
#          m1  tbilrate  unemp      pop  infl  realint
# 0     139.7      2.82    5.8  177.146  0.00     0.00
# 1     141.7      3.08    5.1  177.830  2.34     0.74
# 2     140.5      3.82    5.3  178.657  2.74     1.09
# 3     140.0      4.33    5.6  179.386  0.27     4.06
# 4     139.6      3.50    5.2  180.007  2.31     1.19
# ..      ...       ...    ...      ...   ...      ...
# 198  1474.7      1.17    6.0  305.270 -3.16     4.33
# 199  1576.5      0.12    6.9  305.952 -8.79     8.91
# 200  1592.8      0.22    8.1  306.547  0.94    -0.71
# 201  1653.6      0.18    9.2  307.226  3.37    -3.19
# 202  1673.9      0.12    9.6  308.013  3.56    -3.44
#
# [203 rows x 14 columns]

# %%
# Only select a few variables
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
data
# Out:
#          cpi      m1  tbilrate  unemp
# 0     28.980   139.7      2.82    5.8
# 1     29.150   141.7      3.08    5.1
# 2     29.350   140.5      3.82    5.3
# 3     29.370   140.0      4.33    5.6
# 4     29.540   139.6      3.50    5.2
# ..       ...     ...       ...    ...
# 198  216.889  1474.7      1.17    6.0
# 199  212.174  1576.5      0.12    6.9
# 200  212.671  1592.8      0.22    8.1
# 201  214.469  1653.6      0.18    9.2
# 202  216.385  1673.9      0.12    9.6
#
# [203 rows x 4 columns]

# %% [markdown]
# # **Log transformation**

# %%
# Applies a logarithmic transformation
# Calculates the difference between consecutive values
# Removes any rows with missing values (NaN)
logtrans_data = np.log(data).diff().dropna()

# Display content
logtrans_data
# Out:
#           cpi        m1  tbilrate     unemp
# 1    0.005849  0.014215  0.088193 -0.128617
# 2    0.006838 -0.008505  0.215321  0.038466
# 3    0.000681 -0.003565  0.125317  0.055060
# 4    0.005772 -0.002861 -0.212805 -0.074108
# 5    0.000338  0.004289 -0.266946  0.000000
# ..        ...       ...       ...       ...
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560
#
# [202 rows x 4 columns]

# %%
# Display top few rows for data
data.head()
# Out:
#      cpi     m1  tbilrate  unemp
# 0  28.98  139.7      2.82    5.8
# 1  29.15  141.7      3.08    5.1
# 2  29.35  140.5      3.82    5.3
# 3  29.37  140.0      4.33    5.6
# 4  29.54  139.6      3.50    5.2

# %%
# Check manually
np.log(29.150)-np.log(28.980)
# Out:
# np.float64(0.005848975903965048)

# %%
# Display contents for trans_data
logtrans_data
# Out:
#           cpi        m1  tbilrate     unemp
# 1    0.005849  0.014215  0.088193 -0.128617
# 2    0.006838 -0.008505  0.215321  0.038466
# 3    0.000681 -0.003565  0.125317  0.055060
# 4    0.005772 -0.002861 -0.212805 -0.074108
# 5    0.000338  0.004289 -0.266946  0.000000
# ..        ...       ...       ...       ...
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560
#
# [202 rows x 4 columns]

# %%
# Generate scatter plot with regression line
fig, ax = plt.subplots()
sns.regplot(x='m1', y='unemp', data=logtrans_data, ax=ax)

# Calculate the R-value
r_value = logtrans_data['m1'].corr(logtrans_data['unemp'])

# Add the R-value as text directly on the plot
# 0.05 means 5% of the way from the left edge,
# 0.95 means 95% of the way from the bottom edge (or 5% from the top edge)
ax.text(0.05, 0.95, f'R = {r_value:.2f}', transform=ax.transAxes, fontsize=12, verticalalignment='top')

# Set the title (without R-value)
ax.set(title='Changes in log(unemp) versus log(m1)');

# %%
# kde = kernel density estimate - another name for density plot
# Estimate of the continuous probability distribution
# `scatter_kws` -> scatter keyword arguments
sns.pairplot(logtrans_data, diag_kind='kde', kind='reg',
             plot_kws={'scatter_kws': {'alpha': 0.2}});

# %% [markdown]
# ### **Facet Grids and Categorical Data**
# visualize data with many ***categorical variables***
#
# Seaborn **catplot** function simplifies making many kinds of faceted plots split by ***categorical variables***
#
# ***faceted*** means having many sides

# %%
# Display contents for tips dataframe
tips
# Out:
#      total_bill   tip smoker   day    time  size   tip_pct
# 0         16.99  1.01     No   Sun  Dinner     2  0.059447
# 1         10.34  1.66     No   Sun  Dinner     3  0.160542
# 2         21.01  3.50     No   Sun  Dinner     3  0.166587
# 3         23.68  3.31     No   Sun  Dinner     2  0.139780
# 4         24.59  3.61     No   Sun  Dinner     4  0.146808
# ..          ...   ...    ...   ...     ...   ...       ...
# 239       29.03  5.92     No   Sat  Dinner     3  0.203927
# 240       27.18  2.00    Yes   Sat  Dinner     2  0.073584
# 241       22.67  2.00    Yes   Sat  Dinner     2  0.088222
# 242       17.82  1.75     No   Sat  Dinner     2  0.098204
# 243       18.78  3.00     No  Thur  Dinner     2  0.159744
#
# [244 rows x 7 columns]

# %%
# Generate categorical plot
# col='smoker' -> plots will be arranged in columns based on smoker status
sns.catplot(x='day', y='tip_pct', hue='time', col='smoker',
            kind='bar', data=tips[tips.tip_pct < 1],
            order=['Thur', 'Fri', 'Sat', 'Sun']);

# %%
# Generate categorical plot
sns.catplot(x='day', y='tip_pct', row='time',
            col='smoker', hue='day', order=['Thur', 'Fri', 'Sat', 'Sun'],
            kind='bar', data=tips[tips.tip_pct < 1]);

# %%
# Generate categorical plot: boxplot
sns.catplot(x='tip_pct', y='day', hue='day', kind='box',
            data=tips[tips.tip_pct < 0.5], order=['Thur', 'Fri', 'Sat', 'Sun']);

# %% [markdown]
# # **That's it for the plot!!! :)**
